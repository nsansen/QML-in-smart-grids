# %%
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
# https://discuss.pennylane.ai/t/adding-noise-to-a-keras-hybrid-nn/1241/2
# https://pennylane.ai/qml/demos/tutorial_noisy_circuits
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import pandas as pd
from pennylane import numpy as np
import pennylane as qml
import tensorflow as tf
###################################################################################################
###################################################################################################
Epochs=400
n_qubits = 6#Number of qubits should be the same as number of features, max number = 25
blocks = 1 #Νumber of blocks (AngleEmbedding and StronglyEntanglingLayers is one block )
layers = 1  #layers per block (multiple “layers” of StronglyEntanglingLayers per block )
copy="1" #Number to be set for title
batch_size = 32
LR=0.0001 # Learning rate
splitsequence = 10
p = 0.0 # Noise in depolarizing channel
q = np.tensor(0.0, requires_grad=True) # Noise in amplitude damping channel
model_name = "H1_R" + str(copy) +"_E" + str(Epochs) + "Q" + str(n_qubits) + "B" + str(blocks) + "L" + str(layers) + "_p" + str(p) + "q" + str(q)

def sigmoid(x):
    return 1/(1+np.exp(-x))
###################################################################################################
# Set the seed for weights initialization
seed = 42
tf.random.set_seed(seed)
###################################################################################################
patience= 100 #For early stopping
###################################################################################################
#dev = qml.device("default.qubit.tf", wires=n_qubits) #Run the model in classical CPU
# dev = qml.device("qiskit.aer", wires=n_qubits, shots=1000)
dev = qml.device('default.mixed', wires=n_qubits)
###################################################################################################
# Set the split ratios
train_ratio = 0.75  # 75% for training
val_ratio = 0.15  # 15% for validation
#Target
ms = 'MS377'
#%%
df = pd.read_csv('traffic_mar23.csv',delimiter=';').iloc[:,1:]
d1 = df[ms]
from lstm_data_preparation import lstm_data
x0, y0 = lstm_data(d1,ms,splitsequence)
x0 = x0.reshape(x0.shape[0],x0.shape[1],1)
#%%

# Calculate the lengths of each set
total_length = len(x0)
train_length = int(total_length * train_ratio)
val_length = int(total_length * val_ratio)
test_length = total_length - train_length - val_length
# Split the data
x_train = x0[:train_length]
y_train = y0[:train_length]
x_val = x0[train_length:train_length+val_length]
y_val = y0[train_length:train_length+val_length]
x_test = x0[train_length+val_length:]
y_test = y0[train_length+val_length:]
# Print the shapes of the datasets
print("Training data shape:", x_train.shape, y_train.shape)
print("Validation data shape:", x_val.shape, y_val.shape)
print("Testing data shape:", x_test.shape, y_test.shape)
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
from sklearn.preprocessing import MinMaxScaler
# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
# Scale the training dataset
x_train_scaled = scaler.fit_transform(x_train.reshape(-1, 1)).reshape(x_train.shape)
# Scale the validation dataset
x_val_scaled = scaler.fit_transform(x_val.reshape(-1, 1)).reshape(x_val.shape)
# Scale the test dataset
x_test_scaled = scaler.fit_transform(x_test.reshape(-1, 1)).reshape(x_test.shape)
y_train_scaled =  scaler.fit_transform(y_train.reshape(-1, 1)).reshape(y_train.shape)
y_val_scaled =  scaler.fit_transform(y_val.reshape(-1, 1)).reshape(y_val.shape)
y_test_scaled =  scaler.fit_transform(y_test.reshape(-1, 1)).reshape(y_test.shape)
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################

# Define quantum node
# Added below to ensure the QNode is JIT compiled
@tf.function
@qml.qnode(dev, interface="tf", diff_method="backprop") #diff_method="best"
def qnode(inputs, weights):
    for i in range(blocks):
        qml.templates.AngleEmbedding(inputs, wires=range(n_qubits))
        qml.templates.StronglyEntanglingLayers(weights[i], wires=range(n_qubits)) #STRONGLY ENTANGLING LAYERS
        qml.DepolarizingChannel(p, wires=i)
        qml.AmplitudeDamping(sigmoid(q), wires=i)
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

weights_shape = (blocks, layers, n_qubits, 3) # Uncomment for Strongly entangling layers
tf.keras.backend.set_floatx("float32")
weight_shapes = {"weights": weights_shape}

####### Set seed for constant weights #######
inputs = tf.constant(np.random.random((batch_size, n_qubits))) #uncomment for random weights
#rng = tf.random.Generator.from_seed(seed)
#random_numbers = rng.uniform(shape=(batch_size, n_qubits))
#inputs = tf.constant(random_numbers)
######

##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
##########################-----------##########################
from tensorflow import keras
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.merge import concatenate
from keras.models import Model
from keras.utils.vis_utils import plot_model
from matplotlib import pyplot
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score
#%%
import time

class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)
        
time_callback = TimeHistory()

opt = keras.optimizers.Adam(learning_rate=LR) 
#opt = qml.GradientDescentOptimizer(stepsize=LR)

with tf.device('/device:GPU:0'):
    tf.keras.backend.set_floatx("float32")
    weight_shapes = {"weights": weights_shape}
    layer_1 = tf.keras.layers.LSTM(32,  activation='tanh', input_shape=(x0.shape[1],x0.shape[2]),dtype=tf.float32) ### input shape: timesteps, features
    layer_2 = tf.keras.layers.Dense(6, activation='tanh',  dtype=tf.float32)
    #layer_3 = tf.keras.layers.Dense(64, activation='linear', dtype=tf.float32)
    #layer_4 = tf.keras.layers.Dense(8, activation='linear', dtype=tf.float32)
    layer_P = tf.keras.layers.Dense(n_qubits, activation="tanh", dtype=tf.float32)
    qlayer =  qml.qnn.KerasLayer(qnode, weight_shapes, n_qubits, dtype=tf.float32) 
    #qlayer = tf.keras.layers.Dense(n_qubits, activation="tanh", dtype=tf.float32)
    layer_D = tf.keras.layers.Dense(1, activation="linear")
    model1 = tf.keras.models.Sequential([layer_1,layer_2,layer_P,qlayer,layer_D])
    
   # layer_4=keras.layers.TimeDistributed(Dense(4, activation='relu'))
    
    

#Compile model           
#model1.compile(loss='mse', optimizer=opt, metrics=['mean_absolute_error',"MAPE","MAE"])
model1.compile(loss='mse', optimizer=opt, metrics=['mse',"MAE","MAPE","accuracy"])
                              
# Define the EarlyStopping callback
#early_stopping = EarlyStopping(monitor='mean_absolute_error', patience=patience, verbose=1)
#Fit model
print(model1.summary())
history = model1.fit(x_train_scaled, y_train_scaled, epochs=Epochs, batch_size=batch_size
                     ,validation_data=(x_val_scaled, y_val_scaled), callbacks=[time_callback],shuffle=False)
#%%

# Save the training history to a file
#history_file = model_name + "_history.txt"
#with open(history_file, 'w') as file:
#    file.write(str(history.history))

history_file = model_name + "_Summary.txt"
with open(history_file, 'w') as file:
    # Get the summary of the model architecture as a string
    summary_string = []
    model1.summary(print_fn=lambda x: summary_string.append(x))
# Process the summary string into a pandas DataFrame
    summary_data = [x.split() for x in summary_string[1:-1]]
    summary_df = pd.DataFrame(summary_data, columns=['Layer', 'Output','Shape', 'Param',"type","#"])
    summary_df["blocks"]=blocks
    summary_df["layers"]=layers
    summary_df["LR"]=LR
    summary_df["batch_size"]=batch_size
    summary_df["Epochs"]=Epochs
    summary_df["N_qubits"]=n_qubits
    summary_df["train_ratio"]=train_ratio
    summary_df["val_ratio"]=val_ratio
    file.write(str(summary_df[['Output','Param','blocks','layers',
                               'LR','batch_size','Epochs','N_qubits','train_ratio',
                               'val_ratio']].dropna()))
# make predictions Scaled and unscaled
pred_scaled = model1.predict(x_test_scaled)
pred_unscaled = scaler.inverse_transform(pred_scaled.reshape(-1, 1)).reshape(pred_scaled.shape)
print("------------------")
print("Test MSE:", mean_squared_error(y_test, pred_unscaled))
print("Test RMSE:", np.sqrt(mean_squared_error(y_test, pred_unscaled)))
print("Test MAE:", mean_absolute_error(y_test, pred_unscaled))
print("Test MAPE:", mean_absolute_percentage_error(y_test,pred_unscaled))
print("R2 Score:", r2_score(y_test, pred_unscaled, multioutput='variance_weighted'))
print("------------------")
print("Test MSE scaled:", mean_squared_error(y_test_scaled, pred_scaled))
print("Test RMSE scaled:", np.sqrt(mean_squared_error(y_test_scaled, pred_scaled)))
print("Test MAE scaled:", mean_absolute_error(y_test_scaled, pred_scaled))
print("Test MAPE scaled:", mean_absolute_percentage_error(y_test_scaled,pred_scaled))
print("R2 Score scaled:", r2_score(y_test_scaled, pred_scaled, multioutput='variance_weighted'))
print("------------------")
#%%
import matplotlib.pyplot as plt
plt.plot(y_test, label='Ground truth')
plt.plot(pred_unscaled, label='un-scaled Predictions LSTM')
plt.legend()
plt.show()

plt.plot(y_test_scaled, label='Ground truth')
plt.plot(pred_scaled, label='scaled Predictions LSTM')
plt.legend()
plt.show()

#%%
plt.scatter(pred_scaled, y_test)
plt.show()

# Save the training characteristics
#characteristics_file = model_name + "_characteristics.txt"
#with open(characteristics_file, 'w') as file:
#    file.write("Loss: {}\n".format(history.history['loss'][-1]))
    
#    file.write("Validation Loss: {}\n".format(history.history['val_loss'][-1]))
# Out:
# Training data shape: (402, 10, 1) (402,)
# Validation data shape: (80, 10, 1) (80,)
# Testing data shape: (54, 10, 1) (54,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 6)                 198
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  keras_layer (KerasLayer)    (None, 6)                 0 (unused)
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 4,599
# Trainable params: 4,599
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/400
# C:\Users\Quantum\anaconda3\envs\Quantum2\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: UserWarning: Contains tensors of types {'autograd', 'tensorflow'}; dispatch will prioritize TensorFlow, PyTorch, and  Jax over Autograd. Consider replacing Autograd with vanilla NumPy.
#   return py_builtins.overload_of(f)(*args)
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x000001B08A0EE4C0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x000001B08A0EE4C0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x000001B08A0EE4C0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x000001B08A0EE4C0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method QubitDevice.statistics of <DefaultMixed device (wires=6, shots=None) at 0x1b0bac8f220>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'NoneType' object has no attribute '_fields'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method QubitDevice.statistics of <DefaultMixed device (wires=6, shots=None) at 0x1b0bac8f220>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'NoneType' object has no attribute '_fields'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 13/13 [==============================] - 47s 930ms/step - loss: 0.0582 - mse: 0.0582 - MAE: 0.2108 - MAPE: 1180630.5000 - accuracy: 0.0025 - val_loss: 0.1071 - val_mse: 0.1071 - val_MAE: 0.2981 - val_MAPE: 6012992.0000 - val_accuracy: 0.0125
# Epoch 2/400
# 13/13 [==============================] - 13s 1s/step - loss: 0.0572 - mse: 0.0572 - MAE: 0.2079 - MAPE: 1204034.8750 - accuracy: 0.0025 - val_loss: 0.1034 - val_mse: 0.1034 - val_MAE: 0.2932 - val_MAPE: 6121624.5000 - val_accuracy: 0.0125
# Epoch 3/400
# 13/13 [==============================] - 13s 1s/step - loss: 0.0564 - mse: 0.0564 - MAE: 0.2053 - MAPE: 1224901.0000 - accuracy: 0.0025 - val_loss: 0.1003 - val_mse: 0.1003 - val_MAE: 0.2889 - val_MAPE: 6216959.0000 - val_accuracy: 0.0250
# Epoch 4/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0557 - mse: 0.0557 - MAE: 0.2032 - MAPE: 1242968.6250 - accuracy: 0.0050 - val_loss: 0.0978 - val_mse: 0.0978 - val_MAE: 0.2852 - val_MAPE: 6298853.5000 - val_accuracy: 0.0125
# Epoch 5/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0553 - mse: 0.0553 - MAE: 0.2013 - MAPE: 1258422.0000 - accuracy: 0.0025 - val_loss: 0.0957 - val_mse: 0.0957 - val_MAE: 0.2820 - val_MAPE: 6368617.5000 - val_accuracy: 0.0125
# Epoch 6/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0549 - mse: 0.0549 - MAE: 0.1999 - MAPE: 1271587.1250 - accuracy: 0.0025 - val_loss: 0.0940 - val_mse: 0.0940 - val_MAE: 0.2794 - val_MAPE: 6427902.5000 - val_accuracy: 0.0125
# Epoch 7/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0547 - mse: 0.0547 - MAE: 0.1987 - MAPE: 1282794.7500 - accuracy: 0.0025 - val_loss: 0.0925 - val_mse: 0.0925 - val_MAE: 0.2771 - val_MAPE: 6478237.0000 - val_accuracy: 0.0125
# Epoch 8/400
# 13/13 [==============================] - 16s 1s/step - loss: 0.0545 - mse: 0.0545 - MAE: 0.1977 - MAPE: 1292336.6250 - accuracy: 0.0025 - val_loss: 0.0913 - val_mse: 0.0913 - val_MAE: 0.2751 - val_MAPE: 6520942.5000 - val_accuracy: 0.0125
# Epoch 9/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0543 - mse: 0.0543 - MAE: 0.1969 - MAPE: 1300458.8750 - accuracy: 0.0025 - val_loss: 0.0903 - val_mse: 0.0903 - val_MAE: 0.2735 - val_MAPE: 6557126.5000 - val_accuracy: 0.0125
# Epoch 10/400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0542 - mse: 0.0542 - MAE: 0.1962 - MAPE: 1307369.7500 - accuracy: 0.0025 - val_loss: 0.0895 - val_mse: 0.0895 - val_MAE: 0.2721 - val_MAPE: 6587722.5000 - val_accuracy: 0.0125
# Epoch 11/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.
400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0537 - mse: 0.0537 - MAE: 0.1932 - MAPE: 1341437.8750 - accuracy: 0.0025 - val_loss: 0.0854 - val_mse: 0.0854 - val_MAE: 0.2652 - val_MAPE: 6724585.0000 - val_accuracy: 0.0125
# Epoch 24/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0537 - mse: 0.0537 - MAE: 0.1931 - MAPE: 1342141.1250 - accuracy: 0.0025 - val_loss: 0.0853 - val_mse: 0.0853 - val_MAE: 0.2650 - val_MAPE: 6725721.0000 - val_accuracy: 0.0125
# Epoch 25/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0537 - mse: 0.0537 - MAE: 0.1930 - MAPE: 1342746.6250 - accuracy: 0.0025 - val_loss: 0.0853 - val_mse: 0.0853 - val_MAE: 0.2649 - val_MAPE: 6726264.0000 - val_accuracy: 0.0125
# Epoch 26/400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0536 - mse: 0.0536 - MAE: 0.1929 - MAPE: 1343271.6250 - accuracy: 0.0025 - val_loss: 0.0852 - val_mse: 0.0852 - val_MAE: 0.2648 - val_MAPE: 6726260.0000 - val_accuracy: 0.0125
# Epoch 27/400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0536 - mse: 0.0536 - MAE: 0.1928 - MAPE: 1343727.6250 - accuracy: 0.0025 - val_loss: 0.0851 - val_mse: 0.0851 - val_MAE: 0.2646 - val_MAPE: 6725732.0000 - val_accuracy: 0.0125
# Epoch 28/400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0536 - mse: 0.0536 - MAE: 0.1928 - MAPE: 1344124.5000 - accuracy: 0.0025 - val_loss: 0.0850 - val_mse: 0.0850 - val_MAE: 0.2645 - val_MAPE: 6724690.5000 - val_accuracy: 0.0125
# Epoch 29/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0535 - mse: 0.0535 - MAE: 0.1927 - MAPE: 1344469.3750 - accuracy: 0.0025 - val_loss: 0.0850 - val_mse: 0.0850 - val_MAE: 0.2644 - val_MAPE: 6723120.0000 - val_accuracy: 0.0125
# Epoch 30/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0535 - mse: 0.0535 - MAE: 0.1926 - MAPE: 1344766.8750 - accuracy: 0.0025 - val_loss: 0.0849 - val_mse: 0.0849 - val_MAE: 0.2643 - val_MAPE: 6720992.0000 - val_accuracy: 0.0125
# Epoch 31/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0534 - mse: 0.0534 - MAE: 0.1925 - MAPE: 1345020.3750 - accuracy: 0.0025 - val_loss: 0.0848 - val_mse: 0.0848 - val_MAE: 0.2642 - val_MAPE: 6718251.0000 - val_accuracy: 0.0125
# Epoch 32/400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0534 - mse: 0.0534 - MAE: 0.1924 - MAPE: 1345230.1250 - accuracy: 0.0025 - val_loss: 0.0848 - val_mse: 0.0848 - val_MAE: 0.2642 - val_MAPE: 6714817.5000 - val_accuracy: 0.0125
# Epoch 33/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0533 - mse: 0.0533 - MAE: 0.1924 - MAPE: 1345394.1250 - accuracy: 0.0025 - val_loss: 0.0847 - val_mse: 0.0847 - val_MAE: 0.2641 - val_MAPE: 6710584.5000 - val_accuracy: 0.0125
# Epoch 34/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0533 - mse: 0.0533 - MAE: 0.1923 - MAPE: 1345509.3750 - accuracy: 0.0025 - val_loss: 0.0847 - val_mse: 0.0847 - val_MAE: 0.2640 - val_MAPE: 6705410.5000 - val_accuracy: 0.0125
# Epoch 35/400
# 13/13 [==============================] - 19s 1s/step - loss: 0.
400
# 13/13 [==============================] - 19s 1s/step - loss: 0.0512 - mse: 0.0512 - MAE: 0.1892 - MAPE: 1342446.7500 - accuracy: 0.0025 - val_loss: 0.0835 - val_mse: 0.0835 - val_MAE: 0.2627 - val_MAPE: 6452987.0000 - val_accuracy: 0.0125
# Epoch 48/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0509 - mse: 0.0509 - MAE: 0.1886 - MAPE: 1342955.6250 - accuracy: 0.0025 - val_loss: 0.0832 - val_mse: 0.0832 - val_MAE: 0.2623 - val_MAPE: 6416137.0000 - val_accuracy: 0.0125
# Epoch 49/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0505 - mse: 0.0505 - MAE: 0.1880 - MAPE: 1343968.7500 - accuracy: 0.0025 - val_loss: 0.0828 - val_mse: 0.0828 - val_MAE: 0.2618 - val_MAPE: 6377802.0000 - val_accuracy: 0.0125
# Epoch 50/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0500 - mse: 0.0500 - MAE: 0.1872 - MAPE: 1345585.5000 - accuracy: 0.0025 - val_loss: 0.0823 - val_mse: 0.0823 - val_MAE: 0.2611 - val_MAPE: 6338333.5000 - val_accuracy: 0.0125
# Epoch 51/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0496 - mse: 0.0496 - MAE: 0.1864 - MAPE: 1347891.3750 - accuracy: 0.0025 - val_loss: 0.0818 - val_mse: 0.0818 - val_MAE: 0.2602 - val_MAPE: 6298031.0000 - val_accuracy: 0.0125
# Epoch 52/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0491 - mse: 0.0491 - MAE: 0.1854 - MAPE: 1350960.3750 - accuracy: 0.0025 - val_loss: 0.0811 - val_mse: 0.0811 - val_MAE: 0.2591 - val_MAPE: 6257123.0000 - val_accuracy: 0.0125
# Epoch 53/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0485 - mse: 0.0485 - MAE: 0.1843 - MAPE: 1354852.1250 - accuracy: 0.0025 - val_loss: 0.0803 - val_mse: 0.0803 - val_MAE: 0.2579 - val_MAPE: 6215779.5000 - val_accuracy: 0.0250
# Epoch 54/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0480 - mse: 0.0480 - MAE: 0.1831 - MAPE: 1359612.8750 - accuracy: 0.0025 - val_loss: 0.0794 - val_mse: 0.0794 - val_MAE: 0.2565 - val_MAPE: 6174120.5000 - val_accuracy: 0.0250
# Epoch 55/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0473 - mse: 0.0473 - MAE: 0.1817 - MAPE: 1365277.2500 - accuracy: 0.0025 - val_loss: 0.0784 - val_mse: 0.0784 - val_MAE: 0.2548 - val_MAPE: 6132241.5000 - val_accuracy: 0.0250
# Epoch 56/400
# 13/13 [==============================] - 20s 2s/step - loss: 0.0467 - mse: 0.0467 - MAE: 0.1803 - MAPE: 1371868.8750 - accuracy: 0.0025 - val_loss: 0.0774 - val_mse: 0.0774 - val_MAE: 0.2530 - val_MAPE: 6090207.5000 - val_accuracy: 0.0250
# Epoch 57/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0460 - mse: 0.0460 - MAE: 0.1787 - MAPE: 1379395.6250 - accuracy: 0.0025 - val_loss: 0.0762 - val_mse: 0.0762 - val_MAE: 0.2510 - val_MAPE: 6048086.5000 - val_accuracy: 0.0250
# Epoch 58/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0453 - mse: 0.0453 - MAE: 0.1771 - MAPE: 1387852.0000 - accuracy: 0.0025 - val_loss: 0.0749 - val_mse: 0.0749 - val_MAE: 0.2489 - val_MAPE: 6005928.5000 - val_accuracy: 0.0250
# Epoch 59/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0446 - mse: 0.0446 - MAE: 0.1753 - MAPE: 1397213.6250 - accuracy: 0.0025 - val_loss: 0.0736 - val_mse: 0.0736 - val_MAE: 0.2467 - val_MAPE: 5963790.5000 - val_accuracy: 0.0250
# Epoch 60/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0438 - mse: 0.0438 - MAE: 0.1735 - MAPE: 1407432.2500 - accuracy: 0.0025 - val_loss: 0.0722 - val_mse: 0.0722 - val_MAE: 0.2443 - val_MAPE: 5921715.0000 - val_accuracy: 0.0250
# Epoch 61/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0431 - mse: 0.0431 - MAE: 0.1716 - MAPE: 1418436.8750 - accuracy: 0.0025 - val_loss: 0.0708 - val_mse: 0.0708 - val_MAE: 0.2419 - val_MAPE: 5879757.0000 - val_accuracy: 0.0250
# Epoch 62/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0423 - mse: 0.0423 - MAE: 0.1697 - MAPE: 1430132.3750 - accuracy: 0.0025 - val_loss: 0.0693 - val_mse: 0.0693 - val_MAE: 0.2393 - val_MAPE: 5837963.5000 - val_accuracy: 0.0250
# Epoch 63/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0416 - mse: 0.0416 - MAE: 0.1677 - MAPE: 1442401.1250 - accuracy: 0.0025 - val_loss: 0.0679 - val_mse: 0.0679 - val_MAE: 0.2367 - val_MAPE: 5796411.0000 - val_accuracy: 0.0250
# Epoch 64/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0408 - mse: 0.0408 - MAE: 0.1658 - MAPE: 1455107.3750 - accuracy: 0.0025 - val_loss: 0.0664 - val_mse: 0.0664 - val_MAE: 0.2340 - val_MAPE: 5755165.5000 - val_accuracy: 0.0250
# Epoch 65/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0401 - mse: 0.0401 - MAE: 0.1638 - MAPE: 1468103.3750 - accuracy: 0.0025 - val_loss: 0.0650 - val_mse: 0.0650 - val_MAE: 0.2314 - val_MAPE: 5714315.0000 - val_accuracy: 0.0250
# Epoch 66/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0394 - mse: 0.0394 - MAE: 0.1619 - MAPE: 1481231.2500 - accuracy: 0.0025 - val_loss: 0.0637 - val_mse: 0.0637 - val_MAE: 0.2288 - val_MAPE: 5673932.0000 - val_accuracy: 0.0250
# Epoch 67/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0388 - mse: 0.0388 - MAE: 0.1601 - MAPE: 1494337.3750 - accuracy: 0.0025 - val_loss: 0.0623 - val_mse: 0.0623 - val_MAE: 0.2262 - val_MAPE: 5634073.5000 - val_accuracy: 0.0250
# Epoch 68/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0382 - mse: 0.0382 - MAE: 0.1584 - MAPE: 1507276.1250 - accuracy: 0.0025 - val_loss: 0.0611 - val_mse: 0.0611 - val_MAE: 0.2237 - val_MAPE: 5594777.5000 - val_accuracy: 0.0250
# Epoch 69/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0376 - mse: 0.0376 - MAE: 0.1567 - MAPE: 1519916.2500 - accuracy: 0.0025 - val_loss: 0.0599 - val_mse: 0.0599 - val_MAE: 0.2213 - val_MAPE: 5556053.5000 - val_accuracy: 0.0250
# Epoch 70/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0370 - mse: 0.0370 - MAE: 0.1552 - MAPE: 1532146.2500 - accuracy: 0.0025 - val_loss: 0.0589 - val_mse: 0.0589 - val_MAE: 0.2191 - val_MAPE: 5517901.0000 - val_accuracy: 0.0250
# Epoch 71/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0365 - mse: 0.0365 - MAE: 0.1538 - MAPE: 1543881.2500 - accuracy: 0.0025 - val_loss: 0.0578 - val_mse: 0.0578 - val_MAE: 0.2169 - val_MAPE: 5480301.5000 - val_accuracy: 0.0250
# Epoch 72/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.
400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0135 - mse: 0.0135 - MAE: 0.0836 - MAPE: 1773154.2500 - accuracy: 0.0025 - val_loss: 0.0235 - val_mse: 0.0235 - val_MAE: 0.1338 - val_MAPE: 4589004.0000 - val_accuracy: 0.0250
# Epoch 348/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0135 - mse: 0.0135 - MAE: 0.0835 - MAPE: 1773530.0000 - accuracy: 0.0025 - val_loss: 0.0235 - val_mse: 0.0235 - val_MAE: 0.1337 - val_MAPE: 4590133.0000 - val_accuracy: 0.0250
# Epoch 349/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0135 - mse: 0.0135 - MAE: 0.0833 - MAPE: 1773906.2500 - accuracy: 0.0025 - val_loss: 0.0234 - val_mse: 0.0234 - val_MAE: 0.1336 - val_MAPE: 4591261.0000 - val_accuracy: 0.0250
# Epoch 350/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0134 - mse: 0.0134 - MAE: 0.0832 - MAPE: 1774282.3750 - accuracy: 0.0025 - val_loss: 0.0234 - val_mse: 0.0234 - val_MAE: 0.1335 - val_MAPE: 4592384.5000 - val_accuracy: 0.0250
# Epoch 351/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0134 - mse: 0.0134 - MAE: 0.0831 - MAPE: 1774657.3750 - accuracy: 0.0025 - val_loss: 0.0233 - val_mse: 0.0233 - val_MAE: 0.1333 - val_MAPE: 4593516.5000 - val_accuracy: 0.0250
# Epoch 352/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0134 - mse: 0.0134 - MAE: 0.0830 - MAPE: 1775032.0000 - accuracy: 0.0025 - val_loss: 0.0233 - val_mse: 0.0233 - val_MAE: 0.1332 - val_MAPE: 4594639.0000 - val_accuracy: 0.0250
# Epoch 353/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0133 - mse: 0.0133 - MAE: 0.0828 - MAPE: 1775406.5000 - accuracy: 0.0025 - val_loss: 0.0233 - val_mse: 0.0233 - val_MAE: 0.1331 - val_MAPE: 4595769.5000 - val_accuracy: 0.0250
# Epoch 354/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0133 - mse: 0.0133 - MAE: 0.0827 - MAPE: 1775780.5000 - accuracy: 0.0025 - val_loss: 0.0232 - val_mse: 0.0232 - val_MAE: 0.1329 - val_MAPE: 4596901.0000 - val_accuracy: 0.0250
# Epoch 355/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0133 - mse: 0.0133 - MAE: 0.0826 - MAPE: 1776154.1250 - accuracy: 0.0025 - val_loss: 0.0232 - val_mse: 0.0232 - val_MAE: 0.1328 - val_MAPE: 4598033.0000 - val_accuracy: 0.0250
# Epoch 356/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0133 - mse: 0.0133 - MAE: 0.0825 - MAPE: 1776526.5000 - accuracy: 0.0025 - val_loss: 0.0231 - val_mse: 0.0231 - val_MAE: 0.1327 - val_MAPE: 4599165.0000 - val_accuracy: 0.0250
# Epoch 357/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0132 - mse: 0.0132 - MAE: 0.0823 - MAPE: 1776898.8750 - accuracy: 0.0025 - val_loss: 0.0231 - val_mse: 0.0231 - val_MAE: 0.1326 - val_MAPE: 4600302.0000 - val_accuracy: 0.0250
# Epoch 358/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0132 - mse: 0.0132 - MAE: 0.0822 - MAPE: 1777270.2500 - accuracy: 0.0025 - val_loss: 0.0230 - val_mse: 0.0230 - val_MAE: 0.1324 - val_MAPE: 4601438.0000 - val_accuracy: 0.0250
# Epoch 359/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0132 - mse: 0.0132 - MAE: 0.0821 - MAPE: 1777640.7500 - accuracy: 0.0025 - val_loss: 0.0230 - val_mse: 0.0230 - val_MAE: 0.1323 - val_MAPE: 4602577.0000 - val_accuracy: 0.0250
# Epoch 360/400
# 13/13 [==============================] - 16s 1s/step - loss: 0.0132 - mse: 0.0132 - MAE: 0.0820 - MAPE: 1778011.1250 - accuracy: 0.0025 - val_loss: 0.0229 - val_mse: 0.0229 - val_MAE: 0.1322 - val_MAPE: 4603717.0000 - val_accuracy: 0.0250
# Epoch 361/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0131 - mse: 0.0131 - MAE: 0.0819 - MAPE: 1778380.6250 - accuracy: 0.0025 - val_loss: 0.0229 - val_mse: 0.0229 - val_MAE: 0.1320 - val_MAPE: 4604857.0000 - val_accuracy: 0.0250
# Epoch 362/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0131 - mse: 0.0131 - MAE: 0.0817 - MAPE: 1778749.0000 - accuracy: 0.0025 - val_loss: 0.0228 - val_mse: 0.0228 - val_MAE: 0.1319 - val_MAPE: 4606002.0000 - val_accuracy: 0.0250
# Epoch 363/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0131 - mse: 0.0131 - MAE: 0.0816 - MAPE: 1779117.0000 - accuracy: 0.0025 - val_loss: 0.0228 - val_mse: 0.0228 - val_MAE: 0.1318 - val_MAPE: 4607146.5000 - val_accuracy: 0.0250
# Epoch 364/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0130 - mse: 0.0130 - MAE: 0.0815 - MAPE: 1779483.5000 - accuracy: 0.0025 - val_loss: 0.0227 - val_mse: 0.0227 - val_MAE: 0.1317 - val_MAPE: 4608296.0000 - val_accuracy: 0.0250
# Epoch 365/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0130 - mse: 0.0130 - MAE: 0.0814 - MAPE: 1779849.7500 - accuracy: 0.0025 - val_loss: 0.0227 - val_mse: 0.0227 - val_MAE: 0.1315 - val_MAPE: 4609442.0000 - val_accuracy: 0.0250
# Epoch 366/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0130 - mse: 0.0130 - MAE: 0.0812 - MAPE: 1780214.8750 - accuracy: 0.0025 - val_loss: 0.0227 - val_mse: 0.0227 - val_MAE: 0.1314 - val_MAPE: 4610593.0000 - val_accuracy: 0.0250
# Epoch 367/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0130 - mse: 0.0130 - MAE: 0.0811 - MAPE: 1780579.1250 - accuracy: 0.0025 - val_loss: 0.0226 - val_mse: 0.0226 - val_MAE: 0.1313 - val_MAPE: 4611746.0000 - val_accuracy: 0.0250
# Epoch 368/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0129 - mse: 0.0129 - MAE: 0.0810 - MAPE: 1780942.0000 - accuracy: 0.0025 - val_loss: 0.0226 - val_mse: 0.0226 - val_MAE: 0.1312 - val_MAPE: 4612898.5000 - val_accuracy: 0.0250
# Epoch 369/400
# 13/13 [==============================] - 16s 1s/step - loss: 0.0129 - mse: 0.0129 - MAE: 0.0809 - MAPE: 1781304.2500 - accuracy: 0.0025 - val_loss: 0.0225 - val_mse: 0.0225 - val_MAE: 0.1311 - val_MAPE: 4614059.5000 - val_accuracy: 0.0250
# Epoch 370/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0129 - mse: 0.0129 - MAE: 0.0808 - MAPE: 1781665.2500 - accuracy: 0.0025 - val_loss: 0.0225 - val_mse: 0.0225 - val_MAE: 0.1309 - val_MAPE: 4615209.5000 - val_accuracy: 0.0250
# Epoch 371/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.
400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0126 - mse: 0.0126 - MAE: 0.0794 - MAPE: 1786592.5000 - accuracy: 0.0025 - val_loss: 0.0219 - val_mse: 0.0219 - val_MAE: 0.1292 - val_MAPE: 4631469.5000 - val_accuracy: 0.0250
# Epoch 385/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0125 - mse: 0.0125 - MAE: 0.0793 - MAPE: 1786935.3750 - accuracy: 0.0025 - val_loss: 0.0218 - val_mse: 0.0218 - val_MAE: 0.1291 - val_MAPE: 4632631.0000 - val_accuracy: 0.0250
# Epoch 386/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0125 - mse: 0.0125 - MAE: 0.0792 - MAPE: 1787275.7500 - accuracy: 0.0025 - val_loss: 0.0218 - val_mse: 0.0218 - val_MAE: 0.1290 - val_MAPE: 4633785.0000 - val_accuracy: 0.0250
# Epoch 387/400
# 13/13 [==============================] - 18s 1s/step - loss: 0.0125 - mse: 0.0125 - MAE: 0.0792 - MAPE: 1787615.0000 - accuracy: 0.0025 - val_loss: 0.0218 - val_mse: 0.0218 - val_MAE: 0.1289 - val_MAPE: 4634941.0000 - val_accuracy: 0.0250
# Epoch 388/400
# 13/13 [==============================] - 17s 1s/step - loss: 0.0125 - mse: 0.0125 - MAE: 0.0791 - MAPE: 1787953.2500 - accuracy: 0.0025 - val_loss: 0.0217 - val_mse: 0.0217 - val_MAE: 0.1288 - val_MAPE: 4636093.0000 - val_accuracy: 0.0250
# Epoch 389/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0125 - mse: 0.0125 - MAE: 0.0790 - MAPE: 1788289.6250 - accuracy: 0.0025 - val_loss: 0.0217 - val_mse: 0.0217 - val_MAE: 0.1287 - val_MAPE: 4637245.0000 - val_accuracy: 0.0250
# Epoch 390/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0124 - mse: 0.0124 - MAE: 0.0789 - MAPE: 1788624.3750 - accuracy: 0.0025 - val_loss: 0.0216 - val_mse: 0.0216 - val_MAE: 0.1285 - val_MAPE: 4638394.5000 - val_accuracy: 0.0250
# Epoch 391/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0124 - mse: 0.0124 - MAE: 0.0788 - MAPE: 1788958.1250 - accuracy: 0.0025 - val_loss: 0.0216 - val_mse: 0.0216 - val_MAE: 0.1284 - val_MAPE: 4639542.0000 - val_accuracy: 0.0250
# Epoch 392/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0124 - mse: 0.0124 - MAE: 0.0787 - MAPE: 1789290.3750 - accuracy: 0.0025 - val_loss: 0.0216 - val_mse: 0.0216 - val_MAE: 0.1283 - val_MAPE: 4640685.0000 - val_accuracy: 0.0250
# Epoch 393/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0124 - mse: 0.0124 - MAE: 0.0786 - MAPE: 1789620.5000 - accuracy: 0.0025 - val_loss: 0.0215 - val_mse: 0.0215 - val_MAE: 0.1282 - val_MAPE: 4641825.0000 - val_accuracy: 0.0250
# Epoch 394/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0124 - mse: 0.0124 - MAE: 0.0785 - MAPE: 1789949.6250 - accuracy: 0.0025 - val_loss: 0.0215 - val_mse: 0.0215 - val_MAE: 0.1281 - val_MAPE: 4642964.5000 - val_accuracy: 0.0250
# Epoch 395/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0123 - mse: 0.0123 - MAE: 0.0784 - MAPE: 1790277.1250 - accuracy: 0.0025 - val_loss: 0.0214 - val_mse: 0.0214 - val_MAE: 0.1280 - val_MAPE: 4644101.0000 - val_accuracy: 0.0250
# Epoch 396/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0123 - mse: 0.0123 - MAE: 0.0783 - MAPE: 1790603.2500 - accuracy: 0.0025 - val_loss: 0.0214 - val_mse: 0.0214 - val_MAE: 0.1279 - val_MAPE: 4645235.0000 - val_accuracy: 0.0250
# Epoch 397/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0123 - mse: 0.0123 - MAE: 0.0782 - MAPE: 1790926.7500 - accuracy: 0.0025 - val_loss: 0.0214 - val_mse: 0.0214 - val_MAE: 0.1278 - val_MAPE: 4646363.5000 - val_accuracy: 0.0250
# Epoch 398/400
# 13/13 [==============================] - 16s 1s/step - loss: 0.0123 - mse: 0.0123 - MAE: 0.0781 - MAPE: 1791249.5000 - accuracy: 0.0025 - val_loss: 0.0213 - val_mse: 0.0213 - val_MAE: 0.1277 - val_MAPE: 4647484.0000 - val_accuracy: 0.0250
# Epoch 399/400
# 13/13 [==============================] - 14s 1s/step - loss: 0.0123 - mse: 0.0123 - MAE: 0.0780 - MAPE: 1791570.7500 - accuracy: 0.0025 - val_loss: 0.0213 - val_mse: 0.0213 - val_MAE: 0.1275 - val_MAPE: 4648609.0000 - val_accuracy: 0.0250
# Epoch 400/400
# 13/13 [==============================] - 15s 1s/step - loss: 0.0122 - mse: 0.0122 - MAE: 0.0779 - MAPE: 1791890.1250 - accuracy: 0.0025 - val_loss: 0.0213 - val_mse: 0.0213 - val_MAE: 0.1274 - val_MAPE: 4649726.0000 - val_accuracy: 0.0250
# ------------------
# Test MSE: 36133.407933464034
# Test RMSE: 190.0878952839029
# Test MAE: 173.93411480938946
# Test MAPE: 0.26661108130703887
# R2 Score: 0.8062390883027327
# ------------------
# Test MSE scaled: 0.019001175093165564
# Test RMSE scaled: 0.13784474996591478
# Test MAE scaled: 0.12613062414920512
# Test MAPE scaled: 13536188442094.164
# R2 Score scaled: 0.8062390578879896
# ------------------

# %%
print("Time per epoch")
print(time_callback.times)
# Out:
# Time per epoch
# [46.86492967605591, 13.309244632720947, 13.414159536361694, 14.660284519195557, 14.790440797805786, 15.033383846282959, 14.999996185302734, 15.847528219223022, 17.05113649368286, 18.524479150772095, 18.434131145477295, 17.870004415512085, 18.419076442718506, 18.397122621536255, 18.694883108139038, 17.838381052017212, 18.072120428085327, 18.765204906463623, 18.424873113632202, 18.598998546600342, 17.793737649917603, 18.46028184890747, 18.933831453323364, 17.91201376914978, 17.679466724395752, 19.301278591156006, 19.145289659500122, 18.576162576675415, 17.608631134033203, 17.086827039718628, 18.47123622894287, 18.726478576660156, 17.473190307617188, 18.198642253875732, 18.90619397163391
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training accuracy',linewidth=4)
plt.plot(history.history['val_accuracy'], label='Validation accuracy',linewidth=4)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training mse Loss',linewidth=4)
plt.plot(history.history['val_loss'], label='Validation mse Loss',linewidth=4)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['MAE'], label='Training MAE',linewidth=4)
plt.plot(history.history['val_MAE'], label='Validation MAE',linewidth=4)
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['MAPE'], label='Training MAPE',linewidth=4)
plt.plot(history.history['val_MAPE'], label='Validation MAPE',linewidth=4)
plt.xlabel('Epoch')
plt.ylabel('MAPE')
#plt.ylim(0, 200)  # Set the y-axis limits
plt.legend()
plt.show()

# %% [markdown]
# # Predictions

# %% [markdown]
# ### Predictions scaled

# %%
print("Test MSE:", mean_squared_error(y_test_scaled, pred_scaled,squared=False))
print("Test RMSE:", mean_squared_error(y_test_scaled, pred_scaled,squared=True))
print("Test MAE:", mean_absolute_error(y_test_scaled, pred_scaled))
print("Test MAPE:", mean_absolute_percentage_error(y_test_scaled,pred_scaled))
print("R2 Score:", r2_score(y_test_scaled, pred_scaled, multioutput='variance_weighted'))
#%%
import matplotlib.pyplot as plt
plt.title("Predictions")
plt.plot(y_test_scaled, label='Ground truth',linewidth=4)
plt.plot(pred_scaled, label='scaled Predictions LSTM',linewidth=4)
plt.legend()
plt.show()
# Out:
# Test MSE: 0.13784474996591478
# Test RMSE: 0.019001175093165564
# Test MAE: 0.12613062414920512
# Test MAPE: 13536188442094.164
# R2 Score: 0.8062390578879896

# %% [markdown]
# ### Predictions without scaling

# %%
print("Test MSE:", mean_squared_error(y_test, pred_unscaled,squared=False))
print("Test RMSE:", mean_squared_error(y_test, pred_unscaled,squared=True))
print("Test MAE:", mean_absolute_error(y_test, pred_unscaled))
print("Test MAPE:", mean_absolute_percentage_error(y_test,pred_unscaled)*100)
print("R2 Score:", r2_score(y_test, pred_unscaled, multioutput='variance_weighted'))
#%%
import matplotlib.pyplot as plt
plt.title("Predictions")
plt.plot(y_test, label='Test ',linewidth=4)
plt.plot(pred_unscaled, label='Predictions LSTM',linewidth=4)
plt.legend()
plt.show()
# Out:
# Test MSE: 190.0878952839029
# Test RMSE: 36133.407933464034
# Test MAE: 173.93411480938946
# Test MAPE: 26.661108130703887
# R2 Score: 0.8062390883027327

# %% [markdown]
# # Predictions plots

# %%
plt.figure(figsize=(16, 7))
#plt.plot(np.concatenate((y_train,y_val, y_test)), label='Test ')
plt.plot(np.array(np.concatenate((y_train,y_val, np.array(pred_unscaled).flatten()))), label='QLSTM Predictions', linewidth=5, color="green")
plt.plot(np.concatenate((y_train,y_val,y_test)), label='Real', linewidth=5, color="blue")
plt.ylabel('')
plt.xlabel('Hours')
plt.vlines(len(np.array(y_train)), ymin = min(y_train), ymax = max(y_train), label = "val set start", linestyles = "dashed", linewidth=6, color="grey")
plt.legend()
plt.vlines(len(np.array(np.concatenate((y_train,y_val)))), ymin = min(y_train), ymax = max(y_train), label = "Test set start", linestyles = "dashed", linewidth=6, color="black")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 7))
#plt.plot(np.concatenate((y_train,y_val, y_test)), label='Test ')
plt.plot(np.array(np.concatenate((y_val, np.array(pred_unscaled).flatten()))), label='QLSTM Predictions'
         , linewidth=6, color="green")
plt.plot(np.concatenate((y_val,y_test)), label='Real', linewidth=6, color="blue")
plt.ylabel('')
plt.xlabel('')
plt.vlines(len((y_val)), min(y_train), ymax = max(y_train), label = "Test set start", linestyles = "dashed", linewidth=5, color="black")
plt.legend()
plt.show()

# %%
# Save plots to a file
# Create a DataFrame from the arrays
import pandas as pd
df1 = pd.DataFrame()
file_name = model_name + "_predictions.csv"
arr1=np.concatenate((y_train,y_val,y_test))
arr2=np.concatenate((y_train_scaled,y_val_scaled, np.array(pred_scaled).flatten()))
arr3=np.concatenate((y_train,y_val, np.array(pred_unscaled).flatten()))
#df = pd.DataFrame({'Real': arr1,  'QLSTM': arr2})
# Add the array to the specified column
df1["Q" + str(n_qubits) + "B" + str(blocks) + "L" + str(layers)]=np.nan
df1["Real"] = arr1
df1["Pred s"] = arr2
df1["Pred"] = arr3
df1["----"]=np.nan
df1["test MSE"]=mean_squared_error(y_test_scaled, pred_scaled, squared=False)
df1["test RMSE"]=mean_squared_error(y_test_scaled, pred_scaled, squared=True)
df1["test MAE"]=mean_absolute_error(y_test_scaled, pred_scaled )
df1["test MAPE"]=mean_squared_error(y_test_scaled, pred_scaled)
df1["R2 "]=r2_score(y_test_scaled, pred_scaled, multioutput='variance_weighted')
df1["--~--"]=np.nan
df1["test MSE s"]=mean_squared_error(y_test, pred_unscaled, squared=False)
df1["test RMSEs"]=mean_squared_error(y_test, pred_unscaled, squared=True)
df1["test MAE s"]=mean_absolute_error(y_test, pred_unscaled)
df1["test MAPE s"]=mean_absolute_percentage_error(y_test, pred_unscaled)
df1["R2 s"]=r2_score(y_test, pred_unscaled, multioutput='variance_weighted')
# Save the DataFrame as a CSV file
df1.to_csv(file_name, index=False)
print("Arrays saved as", file_name)
# Out:
# Arrays saved as H1_R1_E400Q6B1L1_p0.0q0.0_predictions.csv

# %%
file_name = model_name + "_history.csv"
df2 = pd.DataFrame()
df2["Q" + str(n_qubits) + "B" + str(blocks) + "L" + str(layers)]=np.nan
df2["loss"]=history.history["loss"]
df2["val_loss"]=history.history["val_loss"]
df2["MAE"]=history.history["MAE"]
df2["val_MAE"]=history.history["val_MAE"]
df2["MAPE"]=history.history["MAPE"]
df2["val_MAPE"]=history.history["val_MAPE"]
df2.to_csv(file_name, index=False)

# %%
#Scaling predictions if needed
array=np.array(np.concatenate((y_val_scaled, np.array(pred_scaled).flatten())))
A = np.array([(x - min(array)) / (max(array) - min(array)) for x in array])
array=np.concatenate((y_val_scaled,y_test_scaled))
B = np.array([(x - min(array)) / (max(array) - min(array)) for x in array])
plt.figure(figsize=(16, 7))
#plt.plot(np.concatenate((y_train,y_val, y_test)), label='Test ')
plt.plot(A, label='QLSTM Predictions'
         , linewidth=6, color="green")
plt.plot(B, label='Real', linewidth=6, color="blue")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(len((y_val)), ymin = 0, ymax = 1, label = "Test set start", linestyles = "dashed", linewidth=5, color="black")
plt.legend()
plt.show()

# %%
#len y_train + y_val
len(np.array(np.concatenate((y_train,y_val))))
# Out:
# 482
